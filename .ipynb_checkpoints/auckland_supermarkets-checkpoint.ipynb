# %%
# install & import libraries
# %pip install geopandas
# %pip install contextily
# Out:
# Requirement already satisfied: geopandas in ./.local/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from geopandas) (21.3)
# Requirement already satisfied: fiona>=1.8.21 in ./.local/lib/python3.10/site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in ./.local/lib/python3.10/site-packages (from geopandas) (1.26.2)
# Requirement already satisfied: pyproj>=3.3.0 in ./.local/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in ./.local/lib/python3.10/site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: pandas>=1.4.0 in ./.local/lib/python3.10/site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: click-plugins>=1.0 in ./.local/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2022.12.7)
# Requirement already satisfied: cligj>=0.5 in ./.local/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (8.1.3)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (22.1.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.local/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->geopandas) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.
# Collecting contextily
#   Downloading contextily-1.6.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from contextily) (1.2.0)
# Requirement already satisfied: matplotlib in ./.local/lib/python3.10/site-packages (from contextily) (3.8.2)
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 37.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: xyzservices in /opt/conda/lib/python3.10/site-packages (from contextily) (2022.9.0)
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 26.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from contextily) (2.28.1)
# Requirement already satisfied: pillow in ./.local/lib/python3.10/site-packages (from contextily) (10.1.0)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: numpy<2,>=1.21 in ./.local/lib/python3.10/site-packages (from matplotlib->contextily) (1.26.2)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.10/site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.10/site-packages (from matplotlib->contextily) (4.46.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.10/site-packages (from matplotlib->contextily) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->contextily) (21.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.local/lib/python3.10/site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: click>=3.0 in /opt/conda/lib/python3.10/site-packages (from mercantile->contextily) (8.1.3)
# Requirement already satisfied: click-plugins in ./.local/lib/python3.10/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from rasterio->contextily) (2022.12.7)
# Requirement already satisfied: attrs in /opt/conda/lib/python3.10/site-packages (from rasterio->contextily) (22.1.0)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from rasterio->contextily) (65.5.1)
# Requirement already satisfied: cligj>=0.5 in ./.local/lib/python3.10/site-packages (from rasterio->contextily) (0.7.2)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->contextily) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->contextily) (2.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Installing collected packages: snuggs, mercantile, geographiclib, affine, rasterio, geopy, contextily
# Successfully installed affine-2.4.0 contextily-1.6.0 geographiclib-2.0 geopy-2.4.1 mercantile-1.2.1 rasterio-1.3.10 snuggs-1.4.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import requests
import contextily as cx

# %%
building_footprints = "layer-101290" # building footprints in NZ
auckland_central_coords_nztm = "5920083.147 1757191.091" # X,Y point for Auckland central in NZTM

# query Land information NZ API 
query = f"https://data.linz.govt.nz/services;key=891b716a68674cce9e536e0729375f3b/wfs?service=WFS&version=2.0.0&request=GetFeature&typeNames={building_footprints}&cql_filter=DWithin(shape,POINT({auckland_central_coords_nztm}),10000,meters) AND use='Supermarket'&outputformat=json"
response = requests.get(query).json()
#response

# %%
# define auckland supermarkets as geopandas dataframe 
supermarkets = gpd.GeoDataFrame.from_features(response['features'])
supermarkets.set_geometry('geometry', inplace=True)
supermarkets.set_crs(epsg=2193, inplace=True)

supermarkets['organisation']  = [text.split()[0] for text in supermarkets['name']] # return organisation from name field 
supermarkets['centroid'] = supermarkets.centroid
supermarkets
# Out:
#                                              geometry  building_id  \
# 0   MULTIPOLYGON (((1758030.719 5920817.455, 17580...      4678708
# 1   MULTIPOLYGON (((1751610.924 5912265.637, 17515...      4678711
# 2   MULTIPOLYGON (((1757594.905 5928928.977, 17576...      4678730
# 3   MULTIPOLYGON (((1752422.413 5918219.637, 17524...      4678749
# 4   MULTIPOLYGON (((1765332.121 5914523.500, 17653...      4678773
# ..                                                ...          ...
# 69  MULTIPOLYGON (((1754357.887 5919856.351, 17543...      4001591
# 70  MULTIPOLYGON (((1753805.511 5914371.464, 17538...      4017159
# 71  MULTIPOLYGON (((1755907.505 5916840.358, 17559...      4024591
# 72  MULTIPOLYGON (((1755214.982 5914770.131, 17551...      4025069
# 73  MULTIPOLYGON (((1757402.583 5921008.286, 17573...      4034179
#
#                              name          use   suburb_locality town_city  \
# 0         Countdown Auckland City  Supermarket  Auckland Central  Auckland
# 1        Countdown Blockhouse Bay  Supermarket    Blockhouse Bay  Auckland
# 2               Countdown Milford  Supermarket           Milford  Auckland
# 3          Countdown Pt Chevalier  Supermarket   Point Chevalier  Auckland
# 4       DaHua Supermarket Panmure  Supermarket           Panmure  Auckland
# ..                            ...          ...               ...       ...
# 69            Countdown Grey Lynn  Supermarket          Westmere  Auckland
# 70           Countdown Mt Roskill  Supermarket            Wesley  Auckland
# 71                  Farro Mt Eden  Supermarket        Mount Eden  Auckland
# 72   Tai Ping Trading Co Dominion  Supermarket     Mount Roskill  Auckland
# 73  Countdown Metro Albert Street  Supermarket  Auckland Central  Auckland
#
#    territorial_authority          capture_method capture_source_group  \
# 0               Auckland  Trace Orthophotography    NZ Aerial Imagery
# 1               Auckland  Trace Orthophotography    NZ Aerial Imagery
# 2               Auckland  Trace Orthophotography    NZ Aerial Imagery
# 3               Auckland  Trace Orthophotography    NZ Aerial Imagery
# 4               Auckland  Trace Orthophotography    NZ Aerial Imagery
# ..                   ...                     ...                  ...
# 69              Auckland      Feature Extraction    NZ Aerial Imagery
# 70              Auckland      Feature Extraction    NZ Aerial Imagery
# 71              Auckland      Feature Extraction    NZ Aerial Imagery
# 72              Auckland      Feature Extraction    NZ Aerial Imagery
# 73              Auckland      Feature Extraction    NZ Aerial Imagery
#
#     capture_source_id                         capture_source_name  \
# 0                1014  Auckland 0.075m Urban Aerial Photos (2017)
# 1                1014  Auckland 0.075m Urban Aerial Photos (2017)
# 2                1014  Auckland 0.075m Urban Aerial Photos (2017)
# 3                1014  Auckland 0.075m Urban Aerial Photos (2017)
# 4                1014  Auckland 0.075m Urban Aerial Photos (2017)
# ..                ...                                         ...
# 69               1014  Auckland 0.075m Urban Aerial Photos (2017)
# 70               1014  Auckland 0.075m Urban Aerial Photos (2017)
# 71               1014  Auckland 0.075m Urban Aerial Photos (2017)
# 72               1014  Auckland 0.075m Urban Aerial Photos (2017)
# 73               1014  Auckland 0.075m Urban Aerial Photos (2017)
#
#    capture_source_from capture_source_to last_modified organisation  \
# 0          2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
# 1          2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
# 2          2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
# 3          2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
# 4          2017-03-15Z       2017-05-06Z   2020-07-01Z        DaHua
# ..                 ...               ...           ...          ...
# 69         2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
# 70         2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
# 71         2017-03-15Z       2017-05-06Z   2020-07-01Z        Farro
# 72         2017-03-15Z       2017-05-06Z   2020-07-01Z          Tai
# 73         2017-03-15Z       2017-05-06Z   2020-07-01Z    Countdown
#
#                            centroid
# 0   POINT (1758074.167 5920829.717)
# 1   POINT (1751616.363 5912287.097)
# 2   POINT (1757631.346 5928937.579)
# 3   POINT (1752433.551 5918208.530)
# 4   POINT (1765350.626 5914531.571)
# ..                              ...
# 69  POINT (1754367.025 5919899.748)
# 70  POINT (1753850.055 5914374.748)
# 71  POINT (1755910.551 5916823.069)
# 72  POINT (1755210.174 5914819.859)
# 73  POINT (1757370.760 5920995.835)
#
# [74 rows x 16 columns]

# %%
# plot auckland supermarkets
supermarkets.set_geometry('centroid', inplace=True) # set geom to centroids for plotting
ax = supermarkets.plot(column='organisation', legend=True, categorical=True, figsize=(12, 12))
cx.add_basemap(ax, crs=supermarkets.crs)
